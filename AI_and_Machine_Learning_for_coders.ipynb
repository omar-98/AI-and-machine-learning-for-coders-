# %% [markdown]
# <a href="https://colab.research.google.com/github/omar-98/AI-and-machine-learning-for-coders-/blob/main/AI_and_Machine_Learning_for_coders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# ### Chapiter 1:**Introduction to TensorFlow**

# %%
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
l0=Dense(units=1,input_shape=[1])
model=Sequential([l0])
model.compile(optimizer='sgd',loss="mean_squared_error")

# %%
xs=np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype=float)
ys=np.array([-3.0,-1.0,1.0,3.0,5.0,7.0],dtype=float)

# %%
model.fit(xs,ys,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 252ms/step - loss: 41.3287
# Epoch 2/500
# 1/1 [==============================] - 0s 4ms/step - loss: 32.8757
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 26.2179
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 20.9726
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 16.8387
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 13.5795
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 11.0084
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.9790
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 7.3758
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 6.1081
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.1044
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.3086
# ...

# %%
model.predict([10.0])
# Out:
# array([[18.977507]], dtype=float32)

# %%
print('here is what he learned :{}'.format(l0.get_weights()))
# Out:
# here is what he learned :[array([[1.9967401]], dtype=float32), array([-0.98989403], dtype=float32)]

# %% [markdown]
#  ### chapter 2: **Introduction to computer vision**

# %%
class mycallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self,epoch,logs={}):
    if logs.get('accuracy')>0.95:
      print('\nReached 95% accuracy so cancelling training')
      self.model.stop_training=True
callbacks=mycallback()

# %%
data=tf.keras.datasets.fashion_mnist
(training_images,trainig_lables),(testing_images,testing_lables)=data.load_data()

# %%
training_images=training_images/255.0
testing_images=testing_images/255.0

# %%
#create our model
model=tf.keras.Sequential([
                           tf.keras.layers.Flatten(input_shape=(28,28)),
                           tf.keras.layers.Dense(128,activation=tf.nn.relu),
                           tf.keras.layers.Dense(10,activation=tf.nn.softmax)
])

# %%
model.compile(optimizer="adam",
              loss='sparse_categorical_crossentropy',
              metrics=["accuracy"])

# %%
model.fit(training_images,trainig_lables,epochs=50,callbacks=callbacks)
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2805 - accuracy: 0.8956
# Epoch 2/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2700 - accuracy: 0.8988
# Epoch 3/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2576 - accuracy: 0.9045
# Epoch 4/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2501 - accuracy: 0.9062
# Epoch 5/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2414 - accuracy: 0.9103
# Epoch 6/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2319 - accuracy: 0.9128
# Epoch 7/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2256 - accuracy: 0.9150
# Epoch 8/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2177 - accuracy: 0.9186
# Epoch 9/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2128 - accuracy: 0.9200
# Epoch 10/50
# ...

# %%
model.evaluate(testing_images,testing_lables)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.4339 - accuracy: 0.8774
# [0.4339185059070587, 0.8773999810218811]

# %%
classification=model.predict(testing_images)

# %%
print(classification[0])
# Out:
# [2.2135244e-05 1.1409322e-06 2.6533946e-06 6.3170082e-06 1.9963951e-05
#  4.8515503e-03 4.0599880e-05 1.8340738e-01 2.4552227e-04 8.1140280e-01]
# 9

# %%
print(testing_lables[0])
# Out:
# 9

# %%
model.summary
# Out:
# <bound method Model.summary of <tensorflow.python.keras.engine.sequential.Sequential object at 0x7fcc137e2490>>

# %% [markdown]
# ### Chapiter 3:**Going beyond th Basics Detecting Features in images**
